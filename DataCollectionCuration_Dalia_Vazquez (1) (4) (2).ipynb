# %% [markdown]
# Dalia Vazquez

# %% [markdown]
# There are certain libraries that are needed to be downloaded in order to be able to read a certain type of data, specially when dealing with spatial data

# %%
# Libraries Needed
import geopandas as gpd # Function to visualize Spatial Data
import matplotlib.pyplot as plt # Helps plot data

# %% [markdown]
# We need to upload our data to jupyternotebooks and create a straight path from the notebook to the

# %%
#Get Data File
gdf = gpd.read_file("data/acs2019_5yr_B17001I_05000US48219.geojson")

# %% [markdown]
# We want to see how big our data really is, gives us a better look at what we are working with

# %%
gdf.shape # how many rows and columns
# Out:
# (255, 121)

# %% [markdown]
# We want to see what the data attributes look like

# %%
gdf.head() # Get the first five rows just to see data
# Out:
#           geoid                 name  B17001I001  B17001I001, Error  \
# 0     04000US48                Texas  10919515.0             2927.0
# 1  05000US48001  Anderson County, TX      7197.0              284.0
# 2  05000US48003   Andrews County, TX     10129.0               28.0
# 3  05000US48005  Angelina County, TX     18853.0              126.0
# 4  05000US48007   Aransas County, TX      6619.0               62.0
#
#    B17001I002  B17001I002, Error  B17001I003  B17001I003, Error  B17001I004  \
# 0   2262560.0            23396.0   1017409.0            12139.0    151977.0
# 1      1437.0              567.0       440.0              215.0         0.0
# 2      1408.0              457.0       581.0              227.0        15.0
# 3      4808.0              911.0      2408.0              521.0       368.0
# 4      2268.0              748.0      1169.0              494.0       138.0
#
#    B17001I004, Error  ...  B17001I055, Error  B17001I056  B17001I056, Error  \
# 0             3070.0  ...             3061.0    536597.0             2553.0
# 1               32.0  ...              136.0       381.0              157.0
# 2               24.0  ...               41.0       443.0               85.0
# 3              149.0  ...              138.0       874.0               78.0
# 4              121.0  ...              129.0       320.0              162.0
#
#    B17001I057  B17001I057, Error  B17001I058  B17001I058, Error  B17001I059  \
# 0    378359.0             1838.0    211877.0             1741.0    131894.0
# 1       223.0               75.0        78.0               56.0        25.0
# 2       321.0               40.0       178.0               81.0        52.0
# 3       557.0               46.0       277.0               95.0        68.0
# 4       253.0               90.0       170.0               89.0       165.0
#
#    B17001I059, Error                                           geometry
# 0             1399.0  MULTIPOLYGON (((-103.98018 32.00012, -103.9799...
# 1               29.0  MULTIPOLYGON (((-95.67753 32.05163, -95.67360 ...
# 2               59.0  MULTIPOLYGON (((-102.86649 32.08714, -102.8666...
# 3               53.0  MULTIPOLYGON (((-94.86268 31.23236, -94.86227 ...
# 4               80.0  MULTIPOLYGON (((-97.20401 28.08081, -97.19783 ...
#
# [5 rows x 121 columns]

# %% [markdown]
# .sample is a function that allows us to get a random data set and I just want to check if the geospatial data is being read correctly

# %%
gdf.sample() # get a random row in the data set
# Out:
#             geoid                name  B17001I001  B17001I001, Error  \
# 130  05000US48259  Kendall County, TX     10326.0               66.0
#
#      B17001I002  B17001I002, Error  B17001I003  B17001I003, Error  B17001I004  \
# 130       987.0              474.0       534.0              269.0       221.0
#
#      B17001I004, Error  ...  B17001I055, Error  B17001I056  B17001I056, Error  \
# 130              133.0  ...               72.0       559.0               77.0
#
#      B17001I057  B17001I057, Error  B17001I058  B17001I058, Error  B17001I059  \
# 130       448.0               20.0       205.0              150.0       186.0
#
#      B17001I059, Error                                           geometry
# 130              150.0  MULTIPOLYGON (((-98.91927 29.85101, -98.91942 ...
#
# [1 rows x 121 columns]

# %%
gdf.plot(figsize=(10,10)) #this function plots the first row of the data set
# Out:
# <AxesSubplot:>

# %% [markdown]
# Above we plotted the first row of on the data set which is just the data set

# %% [markdown]
# Below is the random .sample which is really a random county

# %% [markdown]
# gdf.sample().plot() # plot the sample row

# %% [markdown]
# I want to get the first geoid values

# %%
gdf.geoid.head()
# Out:
# 0       04000US48
# 1    05000US48001
# 2    05000US48003
# 3    05000US48005
# 4    05000US48007
# Name: geoid, dtype: object

# %% [markdown]
# An easy way to just see the rows and columns if you want to look at see a column in specific

# %%
gdf.head() # the first row is for the whole state of texas
# Out:
#           geoid                 name  B17001I001  B17001I001, Error  \
# 0     04000US48                Texas  10919515.0             2927.0
# 1  05000US48001  Anderson County, TX      7197.0              284.0
# 2  05000US48003   Andrews County, TX     10129.0               28.0
# 3  05000US48005  Angelina County, TX     18853.0              126.0
# 4  05000US48007   Aransas County, TX      6619.0               62.0
#
#    B17001I002  B17001I002, Error  B17001I003  B17001I003, Error  B17001I004  \
# 0   2262560.0            23396.0   1017409.0            12139.0    151977.0
# 1      1437.0              567.0       440.0              215.0         0.0
# 2      1408.0              457.0       581.0              227.0        15.0
# 3      4808.0              911.0      2408.0              521.0       368.0
# 4      2268.0              748.0      1169.0              494.0       138.0
#
#    B17001I004, Error  ...  B17001I055, Error  B17001I056  B17001I056, Error  \
# 0             3070.0  ...             3061.0    536597.0             2553.0
# 1               32.0  ...              136.0       381.0              157.0
# 2               24.0  ...               41.0       443.0               85.0
# 3              149.0  ...              138.0       874.0               78.0
# 4              121.0  ...              129.0       320.0              162.0
#
#    B17001I057  B17001I057, Error  B17001I058  B17001I058, Error  B17001I059  \
# 0    378359.0             1838.0    211877.0             1741.0    131894.0
# 1       223.0               75.0        78.0               56.0        25.0
# 2       321.0               40.0       178.0               81.0        52.0
# 3       557.0               46.0       277.0               95.0        68.0
# 4       253.0               90.0       170.0               89.0       165.0
#
#    B17001I059, Error                                           geometry
# 0             1399.0  MULTIPOLYGON (((-103.98018 32.00012, -103.9799...
# 1               29.0  MULTIPOLYGON (((-95.67753 32.05163, -95.67360 ...
# 2               59.0  MULTIPOLYGON (((-102.86649 32.08714, -102.8666...
# 3               53.0  MULTIPOLYGON (((-94.86268 31.23236, -94.86227 ...
# 4               80.0  MULTIPOLYGON (((-97.20401 28.08081, -97.19783 ...
#
# [5 rows x 121 columns]

# %% [markdown]
# I want to drop the first row because we are wanting to create a visualization per county and the state of Texas just includes everything and wont make sense

# %%
gdf = gdf.drop([0]) # Drop the first row because we are wanting to create a visualization per county

# %%
gdf.head() # lets check it it was removed sucessfully
# Out:
#           geoid                 name  B17001I001  B17001I001, Error  \
# 1  05000US48001  Anderson County, TX      7197.0              284.0
# 2  05000US48003   Andrews County, TX     10129.0               28.0
# 3  05000US48005  Angelina County, TX     18853.0              126.0
# 4  05000US48007   Aransas County, TX      6619.0               62.0
# 5  05000US48009    Archer County, TX       711.0               10.0
#
#    B17001I002  B17001I002, Error  B17001I003  B17001I003, Error  B17001I004  \
# 1      1437.0              567.0       440.0              215.0         0.0
# 2      1408.0              457.0       581.0              227.0        15.0
# 3      4808.0              911.0      2408.0              521.0       368.0
# 4      2268.0              748.0      1169.0              494.0       138.0
# 5       129.0               76.0        62.0               38.0         6.0
#
#    B17001I004, Error  ...  B17001I055, Error  B17001I056  B17001I056, Error  \
# 1               32.0  ...              136.0       381.0              157.0
# 2               24.0  ...               41.0       443.0               85.0
# 3              149.0  ...              138.0       874.0               78.0
# 4              121.0  ...              129.0       320.0              162.0
# 5                9.0  ...               23.0        43.0               21.0
#
#    B17001I057  B17001I057, Error  B17001I058  B17001I058, Error  B17001I059  \
# 1       223.0               75.0        78.0               56.0        25.0
# 2       321.0               40.0       178.0               81.0        52.0
# 3       557.0               46.0       277.0               95.0        68.0
# 4       253.0               90.0       170.0               89.0       165.0
# 5        36.0               21.0         0.0               19.0        25.0
#
#    B17001I059, Error                                           geometry
# 1               29.0  MULTIPOLYGON (((-95.67753 32.05163, -95.67360 ...
# 2               59.0  MULTIPOLYGON (((-102.86649 32.08714, -102.8666...
# 3               53.0  MULTIPOLYGON (((-94.86268 31.23236, -94.86227 ...
# 4               80.0  MULTIPOLYGON (((-97.20401 28.08081, -97.19783 ...
# 5               17.0  MULTIPOLYGON (((-98.75200 33.39587, -98.75494 ...
#
# [5 rows x 121 columns]

# %% [markdown]
# IT WAS REMOVED SUCCESSFULLY!

# %% [markdown]
# I want to get a list of all the names of columns

# %%
list(gdf) # lets take a look at all the columns we are working with
# Out:
# ['geoid',
#  'name',
#  'B17001I001',
#  'B17001I001, Error',
#  'B17001I002',
#  'B17001I002, Error',
#  'B17001I003',
#  'B17001I003, Error',
#  'B17001I004',
#  'B17001I004, Error',
#  'B17001I005',
#  'B17001I005, Error',
#  'B17001I006',
#  'B17001I006, Error',
#  'B17001I007',
#  'B17001I007, Error',
#  'B17001I008',
#  'B17001I008, Error',
#  'B17001I009',
#  'B17001I009, Error',
#  'B17001I010',
#  'B17001I010, Error',
#  'B17001I011',
#  'B17001I011, Error',
#  'B17001I012',
#  'B17001I012, Error',
#  'B17001I013',
#  'B17001I013, Error',
#  'B17001I014',
#  'B17001I014, Error',
#  'B17001I015',
#  'B17001I015, Error',
#  'B17001I016',
#  'B17001I016, Error',
#  'B17001I017',
#  'B17001I017, Error',
#  'B17001I018',
#  'B17001I018, Error',
#  'B17001I019',
#  'B17001I019, Error',
#  'B17001I020',
#  'B17001I020, Error',
#  'B17001I021',
#  'B17001I021, Error',
#  'B17001I022',
#  'B17001I022, Error',
#  'B17001I023',
#  'B17001I023, Error',
#  'B17001I024',
#  'B17001I024, Error',
#  'B17001I025',
#  'B17001I025, Error',
#  'B17001I026',
#  'B17001I026, Error',
#  'B17001I027',
#  'B17001I027, Error',
#  'B17001I028',
#  'B17001I028, Error',
#  'B17001I029',
#  'B17001I029, Error',
#  'B17001I030',
#  'B17001I030, Error',
#  'B17001I031',
#  'B17001I031, Error',
#  'B17001I032',
#  'B17001I032, Error',
#  'B17001I033',
#  'B17001I033, Error',
#  'B17001I034',
#  'B17001I034, Error',
#  'B17001I035',
#  'B17001I035, Error',
#  'B17001I036',
#  'B17001I036, Error',
#  'B17001I037',
#  'B17001I037, Error',
#  'B17001I038',
#  'B17001I038, Error',
#  'B17001I039',
#  'B17001I039, Error',
#  'B17001I040',
#  'B17001I040, Error',
#  'B17001I041',
#  'B17001I041, Error',
#  'B17001I042',
#  'B17001I042, Error',
#  'B17001I043',
#  'B17001I043, Error',
#  'B17001I044',
#  'B17001I044, Error',
#  'B17001I045',
#  'B17001I045, Error',
#  'B17001I046',
#  'B17001I046, Error',
#  'B17001I047',
#  'B17001I047, Error',
#  'B17001I048',
#  'B17001I048, Error',
#  'B17001I049',
#  'B17001I049, Error',
#  'B17001I050',
#  'B17001I050, Error',
#  'B17001I051',
#  'B17001I051, Error',
#  'B17001I052',
#  'B17001I052, Error',
#  'B17001I053',
#  'B17001I053, Error',
#  'B17001I054',
#  'B17001I054, Error',
#  'B17001I055',
#  'B17001I055, Error',
#  'B17001I056',
#  'B17001I056, Error',
#  'B17001I057',
#  'B17001I057, Error',
#  'B17001I058',
#  'B17001I058, Error',
#  'B17001I059',
#  'B17001I059, Error',
#  'geometry']

# %% [markdown]
# I am creating a variable to only include the columns i want, i basically looked through the metadata to find out what is what

# %%
# lets filter throught the columns we need
columns_needed = ['geoid',
 'name',
 'B17001I001',
 'B17001I002',
 'B17001I003',
 'B17001I010',
 'B17001I011',
 'B17001I012',
 'B17001I013',
 'B17001I014',
 'B17001I015',
 'B17001I016', 'B17001I017', 'B17001I024', 'B17001I025', 'B17001I026', 'B17001I027', 'B17001I028', 'B17001I029', 'B17001I030',  
 'geometry']

# %% [markdown]
# update the geodataframe, basically it only keeps the columsn we selected

# %%
gdf = gdf[columns_needed] #update our dataframe to only recall the columns we need

# %% [markdown]
# lets check our data set to ensure we only kept the columns we wanted

# %%
gdf.head()
# Out:
#           geoid                 name  B17001I001  B17001I002  B17001I003  \
# 1  05000US48001  Anderson County, TX      7197.0      1437.0       440.0
# 2  05000US48003   Andrews County, TX     10129.0      1408.0       581.0
# 3  05000US48005  Angelina County, TX     18853.0      4808.0      2408.0
# 4  05000US48007   Aransas County, TX      6619.0      2268.0      1169.0
# 5  05000US48009    Archer County, TX       711.0       129.0        62.0
#
#    B17001I010  B17001I011  B17001I012  B17001I013  B17001I014  ...  \
# 1        49.0         0.0        73.0         0.0        21.0  ...
# 2        49.0        10.0        51.0        53.0        27.0  ...
# 3       294.0       263.0       315.0       163.0       109.0  ...
# 4       526.0         3.0         0.0       215.0        88.0  ...
# 5         3.0         0.0        15.0         4.0         2.0  ...
#
#    B17001I016  B17001I017  B17001I024  B17001I025  B17001I026  B17001I027  \
# 1        27.0       997.0       143.0        41.0       148.0        90.0
# 2        60.0       827.0       109.0       115.0        54.0        95.0
# 3        57.0      2400.0       250.0       293.0       405.0        96.0
# 4        73.0      1099.0       217.0       106.0       246.0        58.0
# 5         0.0        67.0         7.0         6.0        13.0         3.0
#
#    B17001I028  B17001I029  B17001I030  \
# 1        21.0        69.0         0.0
# 2        31.0        28.0        16.0
# 3        75.0        88.0        69.0
# 4       102.0        50.0        14.0
# 5         0.0         0.0        18.0
#
#                                             geometry
# 1  MULTIPOLYGON (((-95.67753 32.05163, -95.67360 ...
# 2  MULTIPOLYGON (((-102.86649 32.08714, -102.8666...
# 3  MULTIPOLYGON (((-94.86268 31.23236, -94.86227 ...
# 4  MULTIPOLYGON (((-97.20401 28.08081, -97.19783 ...
# 5  MULTIPOLYGON (((-98.75200 33.39587, -98.75494 ...
#
# [5 rows x 21 columns]

# %% [markdown]
# I want to rename the columns to something that is more understanble to work with

# %%
list(gdf) #get the list of the column names
# Out:
# ['geoid',
#  'name',
#  'Total',
#  'Income in the past 12 months below poverty level:',
#  'Male Total:',
#  'Male 18 to 24 years',
#  'Male 25 to 34 years',
#  'Male 35 to 44 years',
#  'Male 45 to 54 years',
#  'Male 55 to 64 years',
#  'Male 65 to 74 years',
#  'Male 75 years and over',
#  'Female Total:',
#  'Female 18 to 24 years',
#  'Female 25 to 34 years',
#  'Female 35 to 44 years',
#  'Female 45 to 54 years',
#  'Female 55 to 64 years',
#  'Female 65 to 74 years',
#  'Female 75 years and over',
#  'geometry']

# %% [markdown]
# I want to only keep the adult male and female below poverty for my analysis

# %%
# we are renaming the columns names to more easy terms to work with

gdf.columns = ['geoid',
 'name',
 'Total',
 'Income in the past 12 months below poverty level:',
 'Male Total:',
 'Male 18 to 24 years',
 'Male 25 to 34 years',
 'Male 35 to 44 years',
 'Male 45 to 54 years',
 'Male 55 to 64 years',
 'Male 65 to 74 years',
 'Male 75 years and over',
 'Female Total:',
 'Female 18 to 24 years',
 'Female 25 to 34 years',
 'Female 35 to 44 years',
 'Female 45 to 54 years',
 'Female 55 to 64 years',
 'Female 65 to 74 years',
 'Female 75 years and over',
 'geometry']

# %% [markdown]
# You should always double check that your changes are saved.

# %%
gdf.head() # double check the names were updated
# Out:
#           geoid                 name    Total  \
# 1  05000US48001  Anderson County, TX   7197.0
# 2  05000US48003   Andrews County, TX  10129.0
# 3  05000US48005  Angelina County, TX  18853.0
# 4  05000US48007   Aransas County, TX   6619.0
# 5  05000US48009    Archer County, TX    711.0
#
#    Income in the past 12 months below poverty level:  Male Total:  \
# 1                                             1437.0        440.0
# 2                                             1408.0        581.0
# 3                                             4808.0       2408.0
# 4                                             2268.0       1169.0
# 5                                              129.0         62.0
#
#    Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 1                 49.0                  0.0                 73.0
# 2                 49.0                 10.0                 51.0
# 3                294.0                263.0                315.0
# 4                526.0                  3.0                  0.0
# 5                  3.0                  0.0                 15.0
#
#    Male 45 to 54 years  Male 55 to 64 years  ...  Male 75 years and over  \
# 1                  0.0                 21.0  ...                    27.0
# 2                 53.0                 27.0  ...                    60.0
# 3                163.0                109.0  ...                    57.0
# 4                215.0                 88.0  ...                    73.0
# 5                  4.0                  2.0  ...                     0.0
#
#    Female Total:  Female 18 to 24 years  Female 25 to 34 years  \
# 1          997.0                  143.0                   41.0
# 2          827.0                  109.0                  115.0
# 3         2400.0                  250.0                  293.0
# 4         1099.0                  217.0                  106.0
# 5           67.0                    7.0                    6.0
#
#    Female 35 to 44 years  Female 45 to 54 years  Female 55 to 64 years  \
# 1                  148.0                   90.0                   21.0
# 2                   54.0                   95.0                   31.0
# 3                  405.0                   96.0                   75.0
# 4                  246.0                   58.0                  102.0
# 5                   13.0                    3.0                    0.0
#
#    Female 65 to 74 years  Female 75 years and over  \
# 1                   69.0                       0.0
# 2                   28.0                      16.0
# 3                   88.0                      69.0
# 4                   50.0                      14.0
# 5                    0.0                      18.0
#
#                                             geometry
# 1  MULTIPOLYGON (((-95.67753 32.05163, -95.67360 ...
# 2  MULTIPOLYGON (((-102.86649 32.08714, -102.8666...
# 3  MULTIPOLYGON (((-94.86268 31.23236, -94.86227 ...
# 4  MULTIPOLYGON (((-97.20401 28.08081, -97.19783 ...
# 5  MULTIPOLYGON (((-98.75200 33.39587, -98.75494 ...
#
# [5 rows x 21 columns]

# %% [markdown]
# I want to see if the total female makes sense, since the original female total included children as well

# %%
gdf['Female Total:'].head() # Lets look at the first 5 values for female total, shows us the type of data we are working with
# Out:
# 1     997.0
# 2     827.0
# 3    2400.0
# 4    1099.0
# 5      67.0
# Name: Female Total:, dtype: float64

# %% [markdown]
# Does not make sense, but we will work on it

# %% [markdown]
# Here I am just testing out some functions such which counties have the highest below poverty concentrations

# %%
gdf_sorted = gdf.sort_values(by='Female Total:',ascending = False) # ascend the Female Total column

# %%
gdf_sorted[['name','Female Total:']].head(10) # get the top 10 counties with the highest female pop below poverty
# Out:
#                    name  Female Total:
# 101   Harris County, TX       227813.0
# 108  Hidalgo County, TX       134543.0
# 15     Bexar County, TX       117609.0
# 57    Dallas County, TX       109206.0
# 71   El Paso County, TX        85528.0
# 31   Cameron County, TX        62082.0
# 220  Tarrant County, TX        57009.0
# 240     Webb County, TX        39898.0
# 227   Travis County, TX        38363.0
# 178   Nueces County, TX        23956.0

# %%
gdf_sorted.head(10).plot(figsize=(10,10)) # lets plot the results from above. This will only provide us with the coordinates of the top 10 counties, it is showing where they are located
# Out:
# <AxesSubplot:>

# %% [markdown]
# This above just shows the top 10 counties and the coordinate system

# %% [markdown]
# Demonstrate all 254 counties and the female total below the poverty rate
# not very useful or accurate because we are just diplaying the total and comparing the rate of the total amongst all women below the poverty level
# the current female total includes children which makes this analysis inaccurate

# %%
#plot a map of all 254 counties to see what it looks like

gdf_sorted.head(254).plot(figsize=(10,10),
                          column='Female Total:', 
                          cmap='inferno', 
                          legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# we need to update the male and female totals to only include the adults and not the children

# %%
# calculation to update totals

gdf['Female Total:'] =   gdf['Female 18 to 24 years'] + gdf['Female 25 to 34 years'] + gdf['Female 35 to 44 years'] + gdf['Female 45 to 54 years'] + gdf['Female 55 to 64 years'] + gdf['Female 65 to 74 years'] + gdf['Female 75 years and over']
gdf['Male Total:'] =   gdf['Male 18 to 24 years'] + gdf['Male 25 to 34 years'] + gdf['Male 35 to 44 years'] + gdf['Male 45 to 54 years'] + gdf['Male 55 to 64 years'] + gdf['Male 65 to 74 years'] + gdf['Male 75 years and over']

# %% [markdown]
# get a sample to make sure that the total add up and are updated

# %%
gdf.sample(5)
# Out:
#             geoid                  name    Total  \
# 251  05000US48501     Yoakum County, TX   5736.0
# 2    05000US48003    Andrews County, TX  10129.0
# 161  05000US48321  Matagorda County, TX  15523.0
# 245  05000US48489    Willacy County, TX  17917.0
# 226  05000US48451  Tom Green County, TX  45553.0
#
#      Income in the past 12 months below poverty level:  Male Total:  \
# 251                                              568.0        121.0
# 2                                               1408.0        309.0
# 161                                             3481.0        589.0
# 245                                             5028.0       1493.0
# 226                                             7485.0       1272.0
#
#      Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 251                 12.0                  3.0                 64.0
# 2                   49.0                 10.0                 51.0
# 161                  4.0                 87.0                125.0
# 245                314.0                311.0                162.0
# 226                238.0                296.0                257.0
#
#      Male 45 to 54 years  Male 55 to 64 years  ...  Male 75 years and over  \
# 251                 14.0                 13.0  ...                     0.0
# 2                   53.0                 27.0  ...                    60.0
# 161                157.0                 30.0  ...                    54.0
# 245                189.0                257.0  ...                    97.0
# 226                199.0                135.0  ...                    32.0
#
#      Female Total:  Female 18 to 24 years  Female 25 to 34 years  \
# 251          155.0                   23.0                   29.0
# 2            448.0                  109.0                  115.0
# 161         1105.0                  161.0                  184.0
# 245         1600.0                  340.0                  265.0
# 226         2716.0                  342.0                  868.0
#
#      Female 35 to 44 years  Female 45 to 54 years  Female 55 to 64 years  \
# 251                   41.0                   17.0                    0.0
# 2                     54.0                   95.0                   31.0
# 161                  294.0                  142.0                  122.0
# 245                  259.0                  210.0                  245.0
# 226                  314.0                  306.0                  362.0
#
#      Female 65 to 74 years  Female 75 years and over  \
# 251                   45.0                       0.0
# 2                     28.0                      16.0
# 161                   81.0                     121.0
# 245                  119.0                     162.0
# 226                  304.0                     220.0
#
#                                               geometry
# 251  MULTIPOLYGON (((-103.06324 33.06621, -103.0632...
# 2    MULTIPOLYGON (((-102.86649 32.08714, -102.8666...
# 161  MULTIPOLYGON (((-96.31734 28.79007, -96.31719 ...
# 245  MULTIPOLYGON (((-97.87238 26.43353, -97.87528 ...
# 226  MULTIPOLYGON (((-100.44159 31.69307, -100.4415...
#
# [5 rows x 21 columns]

# %% [markdown]
# We need to update the total population of male plus female

# %%
gdf['Total'] = gdf['Male Total:'] + gdf['Female Total:'] # update the total column by adding the new and updated male and female totals

# %%
gdf.sample(5) # get a sample ensure it was updated
# Out:
#             geoid                  name   Total  \
# 233  05000US48465  Val Verde County, TX  4757.0
# 75   05000US48149    Fayette County, TX   549.0
# 23   05000US48045    Briscoe County, TX   111.0
# 107  05000US48213  Henderson County, TX  1487.0
# 137  05000US48273    Kleberg County, TX  4000.0
#
#      Income in the past 12 months below poverty level:  Male Total:  \
# 233                                             8591.0       1833.0
# 75                                               792.0        162.0
# 23                                               127.0         81.0
# 107                                             3238.0        778.0
# 137                                             6314.0       1624.0
#
#      Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 233                382.0                203.0                196.0
# 75                   5.0                 11.0                 56.0
# 23                   5.0                  0.0                 31.0
# 107                219.0                211.0                233.0
# 137                767.0                245.0                199.0
#
#      Male 45 to 54 years  Male 55 to 64 years  ...  Male 75 years and over  \
# 233                221.0                270.0  ...                   350.0
# 75                   0.0                 37.0  ...                     0.0
# 23                   0.0                 15.0  ...                     0.0
# 107                 24.0                 16.0  ...                    14.0
# 137                127.0                197.0  ...                    23.0
#
#      Female Total:  Female 18 to 24 years  Female 25 to 34 years  \
# 233         2924.0                  335.0                  554.0
# 75           387.0                   68.0                   29.0
# 23            30.0                    6.0                    4.0
# 107          709.0                  106.0                  260.0
# 137         2376.0                  948.0                  647.0
#
#      Female 35 to 44 years  Female 45 to 54 years  Female 55 to 64 years  \
# 233                  560.0                  369.0                  341.0
# 75                   154.0                   39.0                   61.0
# 23                    11.0                    6.0                    0.0
# 107                  200.0                  108.0                    6.0
# 137                  168.0                  167.0                  113.0
#
#      Female 65 to 74 years  Female 75 years and over  \
# 233                  373.0                     392.0
# 75                    27.0                       9.0
# 23                     0.0                       3.0
# 107                   24.0                       5.0
# 137                  130.0                     203.0
#
#                                               geometry
# 233  MULTIPOLYGON (((-101.06398 29.45985, -101.0674...
# 75   MULTIPOLYGON (((-97.08646 29.99430, -97.08616 ...
# 23   MULTIPOLYGON (((-101.27948 34.74827, -101.2793...
# 107  MULTIPOLYGON (((-95.94052 32.35708, -95.94050 ...
# 137  MULTIPOLYGON (((-98.05874 27.39206, -98.05874 ...
#
# [5 rows x 21 columns]

# %% [markdown]
# create a new column to normalize the data by gender
# we can do this by using the female total and dividing the total pop below poverty and multiply by 100 to get the percent

# %%
#divide the total pop below poverty and multiply by 100 to get the percent
gdf['Percent of Latinas in Poverty'] = gdf['Female Total:'] / gdf['Total'] * 100

# %%
gdf.sample(5) # make sure the column is present
# Out:
#             geoid                 name   Total  \
# 22   05000US48043  Brewster County, TX   376.0
# 106  05000US48211  Hemphill County, TX   117.0
# 9    05000US48017    Bailey County, TX   302.0
# 143  05000US48285    Lavaca County, TX   347.0
# 126  05000US48251   Johnson County, TX  2517.0
#
#      Income in the past 12 months below poverty level:  Male Total:  \
# 22                                               509.0        185.0
# 106                                              295.0         57.0
# 9                                                493.0         74.0
# 143                                              701.0        138.0
# 126                                             5369.0        947.0
#
#      Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 22                  35.0                  6.0                 86.0
# 106                  0.0                 23.0                 34.0
# 9                    0.0                 15.0                  1.0
# 143                  8.0                 46.0                 30.0
# 126                182.0                143.0                263.0
#
#      Male 45 to 54 years  Male 55 to 64 years  ...  Female Total:  \
# 22                  13.0                 12.0  ...          191.0
# 106                  0.0                  0.0  ...           60.0
# 9                    0.0                 43.0  ...          228.0
# 143                 19.0                  0.0  ...          209.0
# 126                204.0                 98.0  ...         1570.0
#
#      Female 18 to 24 years  Female 25 to 34 years  Female 35 to 44 years  \
# 22                    51.0                    6.0                   31.0
# 106                    0.0                   14.0                   23.0
# 9                     92.0                    9.0                   26.0
# 143                   80.0                   49.0                   17.0
# 126                  376.0                  426.0                  423.0
#
#      Female 45 to 54 years  Female 55 to 64 years  Female 65 to 74 years  \
# 22                     9.0                   13.0                   22.0
# 106                    0.0                   23.0                    0.0
# 9                     60.0                   41.0                    0.0
# 143                   18.0                   35.0                    7.0
# 126                  180.0                   63.0                   52.0
#
#      Female 75 years and over  \
# 22                       59.0
# 106                       0.0
# 9                         0.0
# 143                       3.0
# 126                      50.0
#
#                                               geometry  \
# 22   MULTIPOLYGON (((-103.32540 30.58609, -103.3253...
# 106  MULTIPOLYGON (((-100.54102 35.74739, -100.5410...
# 9    MULTIPOLYGON (((-103.04384 34.11283, -103.0438...
# 143  MULTIPOLYGON (((-97.20270 29.34559, -97.20423 ...
# 126  MULTIPOLYGON (((-97.50342 32.55544, -97.49425 ...
#
#      Percent of Latinas in Poverty
# 22                       50.797872
# 106                      51.282051
# 9                        75.496689
# 143                      60.230548
# 126                      62.375844
#
# [5 rows x 22 columns]

# %% [markdown]
# Do the same for male percentage

# %%
# male total and dividing the total pop below poverty and multiply by 100 to get the percent

gdf['Percent of Latinos in Poverty'] = gdf['Male Total:'] / gdf['Total'] * 100

# %%
gdf.sample(5)  # make sure column is present
# Out:
#             geoid                 name  Total  \
# 47   05000US48093  Comanche County, TX  174.0
# 186  05000US48371     Pecos County, TX  968.0
# 50   05000US48099   Coryell County, TX  877.0
# 119  05000US48237      Jack County, TX  148.0
# 75   05000US48149   Fayette County, TX  549.0
#
#      Income in the past 12 months below poverty level:  Male Total:  \
# 47                                               336.0         84.0
# 186                                             1849.0        372.0
# 50                                              1749.0        368.0
# 119                                              327.0         62.0
# 75                                               792.0        162.0
#
#      Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 47                  22.0                  5.0                 25.0
# 186                 67.0                 46.0                 51.0
# 50                  30.0                132.0                109.0
# 119                  6.0                 20.0                 15.0
# 75                   5.0                 11.0                 56.0
#
#      Male 45 to 54 years  Male 55 to 64 years  ...  Female 18 to 24 years  \
# 47                   0.0                  9.0  ...                   18.0
# 186                 17.0                 67.0  ...                   97.0
# 50                  33.0                  8.0  ...                  120.0
# 119                  1.0                  9.0  ...                    0.0
# 75                   0.0                 37.0  ...                   68.0
#
#      Female 25 to 34 years  Female 35 to 44 years  Female 45 to 54 years  \
# 47                     5.0                   22.0                   15.0
# 186                   89.0                   53.0                   83.0
# 50                   117.0                  110.0                   71.0
# 119                    0.0                   27.0                   26.0
# 75                    29.0                  154.0                   39.0
#
#      Female 55 to 64 years  Female 65 to 74 years  Female 75 years and over  \
# 47                     4.0                   16.0                      10.0
# 186                   68.0                  119.0                      87.0
# 50                    39.0                   35.0                      17.0
# 119                   19.0                    7.0                       7.0
# 75                    61.0                   27.0                       9.0
#
#                                               geometry  \
# 47   MULTIPOLYGON (((-98.88707 32.09600, -98.88684 ...
# 186  MULTIPOLYGON (((-103.25346 31.11715, -103.2524...
# 50   MULTIPOLYGON (((-98.07609 31.51618, -98.07308 ...
# 119  MULTIPOLYGON (((-98.42091 33.29791, -98.42091 ...
# 75   MULTIPOLYGON (((-97.08646 29.99430, -97.08616 ...
#
#      Percent of Latinas in Poverty  Percent of Latinos in Poverty
# 47                       51.724138                      48.275862
# 186                      61.570248                      38.429752
# 50                       58.038769                      41.961231
# 119                      58.108108                      41.891892
# 75                       70.491803                      29.508197
#
# [5 rows x 23 columns]

# %% [markdown]
# Create 1X2 subplot and show the percentage of male and female adult latinos living below poverty. I want to do a side by side for now, this will allows us to see any trends per county and any significant patterns through the cluster of counties. We will do natural breaks to get a more real and dense analysis since we are working with percentages. We will add a legend and use a inferno color scheme to have a more clear map. We will also be setting the axis on in order to get the lat and longs

# %%
# we will create a 1x2 subplots
fig, axs = plt.subplots(1, 2, figsize=(15, 12))
ax1, ax2 = axs

# percent of Latinas below poverty rate 
gdf.plot(column='Percent of Latinas in Poverty', #column you want to use
            cmap='inferno', #color scheme 
            scheme='naturalbreaks',# what type of break do you want
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, # what axis are we assining it to 
            legend=True) # add legend

ax1.axis("on")
ax1.set_title("Percent of Latinas Living Below Poverty (Past 12 Months)")

# percent of Latinos below poverty rate
gdf.plot(column='Percent of Latinos in Poverty', #column you want to use 
            cmap='inferno', #color scheme
            scheme='naturalbreaks', # what type of break do you want
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax2, # what axis are we assining it to 
            legend=True)# add legend
ax2.axis("on")
ax2.set_title("Percent of Latinos Living Below Poverty (Past 12 Months) ")
# Out:
# Text(0.5, 1.0, 'Percent of Latinos Living Below Poverty (Past 12 Months) ')

# %% [markdown]
# The map visualization above represents the Male and Female percent of the total Latino population living below the poverty level for every county in Texas.
