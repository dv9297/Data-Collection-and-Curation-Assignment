# %%
# Libraries Needed
import geopandas as gpd # Function to visualize Spatial Data

# to give more power to your figures (plots)
import matplotlib.pyplot as plt

# %%
# load a data file
# note the relative filepath! where is this file located?
gdf = gpd.read_file("data/acs2019_5yr_B17001I_05000US48219.geojson")

# %%
gdf.shape
# Out:
# (255, 121)

# %%
gdf.head()
# Out:
#           geoid                 name  B17001I001  B17001I001, Error  \
# 0     04000US48                Texas  10919515.0             2927.0
# 1  05000US48001  Anderson County, TX      7197.0              284.0
# 2  05000US48003   Andrews County, TX     10129.0               28.0
# 3  05000US48005  Angelina County, TX     18853.0              126.0
# 4  05000US48007   Aransas County, TX      6619.0               62.0
#
#    B17001I002  B17001I002, Error  B17001I003  B17001I003, Error  B17001I004  \
# 0   2262560.0            23396.0   1017409.0            12139.0    151977.0
# 1      1437.0              567.0       440.0              215.0         0.0
# 2      1408.0              457.0       581.0              227.0        15.0
# 3      4808.0              911.0      2408.0              521.0       368.0
# 4      2268.0              748.0      1169.0              494.0       138.0
#
#    B17001I004, Error  ...  B17001I055, Error  B17001I056  B17001I056, Error  \
# ...

# %%
gdf.sample()
# Out:
#             geoid               name  B17001I001  B17001I001, Error  \
# 101  05000US48201  Harris County, TX   1983274.0             1388.0
#
#      B17001I002  B17001I002, Error  B17001I003  B17001I003, Error  B17001I004  \
# 101    412610.0            10123.0    184797.0             5465.0     29145.0
#
#      B17001I004, Error  ...  B17001I055, Error  B17001I056  B17001I056, Error  \
# 101             1483.0  ...             1247.0     96254.0             1110.0
#
#      B17001I057  B17001I057, Error  B17001I058  B17001I058, Error  B17001I059  \
# 101     63366.0              830.0     29842.0              669.0     17041.0
#
#      B17001I059, Error                                           geometry
# 101              506.0  MULTIPOLYGON (((-95.85685 29.87458, -95.85686 ...
#
# [1 rows x 121 columns]

# %%
gdf.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
gdf.sample().plot()
# Out:
# <AxesSubplot:>

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Columns: 121 entries, geoid to geometry
# dtypes: float64(118), geometry(1), object(2)
# memory usage: 241.2+ KB

# %%
gdf.geoid.head()
# Out:
# 0       04000US48
# 1    05000US48001
# 2    05000US48003
# 3    05000US48005
# 4    05000US48007
# Name: geoid, dtype: object

# %%
gdf.head()
# Out:
#           geoid                 name  B17001I001  B17001I001, Error  \
# 0     04000US48                Texas  10919515.0             2927.0
# 1  05000US48001  Anderson County, TX      7197.0              284.0
# 2  05000US48003   Andrews County, TX     10129.0               28.0
# 3  05000US48005  Angelina County, TX     18853.0              126.0
# 4  05000US48007   Aransas County, TX      6619.0               62.0
#
#    B17001I002  B17001I002, Error  B17001I003  B17001I003, Error  B17001I004  \
# 0   2262560.0            23396.0   1017409.0            12139.0    151977.0
# 1      1437.0              567.0       440.0              215.0         0.0
# 2      1408.0              457.0       581.0              227.0        15.0
# 3      4808.0              911.0      2408.0              521.0       368.0
# 4      2268.0              748.0      1169.0              494.0       138.0
#
#    B17001I004, Error  ...  B17001I055, Error  B17001I056  B17001I056, Error  \
# ...

# %%
# drop the row with index 0 (i.e. the first row)
gdf = gdf.drop([0])

# %%
gdf.head()
# Out:
#           geoid                 name  B17001I001  B17001I001, Error  \
# 1  05000US48001  Anderson County, TX      7197.0              284.0
# 2  05000US48003   Andrews County, TX     10129.0               28.0
# 3  05000US48005  Angelina County, TX     18853.0              126.0
# 4  05000US48007   Aransas County, TX      6619.0               62.0
# 5  05000US48009    Archer County, TX       711.0               10.0
#
#    B17001I002  B17001I002, Error  B17001I003  B17001I003, Error  B17001I004  \
# 1      1437.0              567.0       440.0              215.0         0.0
# 2      1408.0              457.0       581.0              227.0        15.0
# 3      4808.0              911.0      2408.0              521.0       368.0
# 4      2268.0              748.0      1169.0              494.0       138.0
# 5       129.0               76.0        62.0               38.0         6.0
#
#    B17001I004, Error  ...  B17001I055, Error  B17001I056  B17001I056, Error  \
# ...

# %%
list(gdf)
# Out:
# ['geoid',
#  'name',
#  'B17001I001',
#  'B17001I001, Error',
#  'B17001I002',
#  'B17001I002, Error',
#  'B17001I003',
#  'B17001I003, Error',
#  'B17001I004',
#  'B17001I004, Error',
#  'B17001I005',
#  'B17001I005, Error',
#  'B17001I006',
#  'B17001I006, Error',
#  'B17001I007',
#  'B17001I007, Error',
#  'B17001I008',
#  'B17001I008, Error',
#  'B17001I009',
#  'B17001I009, Error',
#  'B17001I010',
#  'B17001I010, Error',
#  'B17001I011',
#  'B17001I011, Error',
#  'B17001I012',
#  'B17001I012, Error',
#  'B17001I013',
#  'B17001I013, Error',
#  'B17001I014',
#  'B17001I014, Error',
#  'B17001I015',
#  'B17001I015, Error',
#  'B17001I016',
#  'B17001I016, Error',
#  'B17001I017',
#  'B17001I017, Error',
#  'B17001I018',
#  'B17001I018, Error',
#  'B17001I019',
#  'B17001I019, Error',
#  'B17001I020',
#  'B17001I020, Error',
#  'B17001I021',
#  'B17001I021, Error',
#  'B17001I022',
#  'B17001I022, Error',
#  'B17001I023',
#  'B17001I023, Error',
#  'B17001I024',
# ...

# %%
# create a list of columns to keep
columns_to_keep = ['geoid',
 'name',
 'B17001I001',
 'B17001I002',
 'B17001I003',
 'B17001I010',
 'B17001I011',
 'B17001I012',
 'B17001I013',
 'B17001I014',
 'B17001I015',
 'B17001I016', 'B17001I017', 'B17001I024', 'B17001I025', 'B17001I026', 'B17001I027', 'B17001I028', 'B17001I029', 'B17001I030',  
 'geometry']

# %%
gdf = gdf[columns_to_keep]

# %%
gdf.head()
# Out:
#           geoid                 name  B17001I001  B17001I002  B17001I003  \
# 1  05000US48001  Anderson County, TX      7197.0      1437.0       440.0
# 2  05000US48003   Andrews County, TX     10129.0      1408.0       581.0
# 3  05000US48005  Angelina County, TX     18853.0      4808.0      2408.0
# 4  05000US48007   Aransas County, TX      6619.0      2268.0      1169.0
# 5  05000US48009    Archer County, TX       711.0       129.0        62.0
#
#    B17001I010  B17001I011  B17001I012  B17001I013  B17001I014  ...  \
# 1        49.0         0.0        73.0         0.0        21.0  ...
# 2        49.0        10.0        51.0        53.0        27.0  ...
# 3       294.0       263.0       315.0       163.0       109.0  ...
# 4       526.0         3.0         0.0       215.0        88.0  ...
# 5         3.0         0.0        15.0         4.0         2.0  ...
#
#    B17001I016  B17001I017  B17001I024  B17001I025  B17001I026  B17001I027  \
# ...

# %%
list(gdf)
# Out:
# ['geoid',
#  'name',
#  'B17001I001',
#  'B17001I002',
#  'B17001I003',
#  'B17001I010',
#  'B17001I011',
#  'B17001I012',
#  'B17001I013',
#  'B17001I014',
#  'B17001I015',
#  'B17001I016',
#  'B17001I017',
#  'B17001I024',
#  'B17001I025',
#  'B17001I026',
#  'B17001I027',
#  'B17001I028',
#  'B17001I029',
#  'B17001I030',
#  'geometry']

# %%
gdf.columns = ['geoid',
 'name',
 'Total',
 'Income in the past 12 months below poverty level:',
 'Male Total:',
 'Male 18 to 24 years',
 'Male 25 to 34 years',
 'Male 35 to 44 years',
 'Male 45 to 54 years',
 'Male 55 to 64 years',
 'Male65 to 74 years',
 'Male 75 years and over',
 'Female Total:',
 'Female 18 to 24 years',
 'Female 25 to 34 years',
 'Female35 to 44 years',
 'Female 45 to 54 years',
 'Female 55 to 64 years',
 'Female 65 to 74 years',
 'Female 75 years and over',
 'geometry']

# %%
gdf.head()
# Out:
#           geoid                 name    Total  \
# 1  05000US48001  Anderson County, TX   7197.0
# 2  05000US48003   Andrews County, TX  10129.0
# 3  05000US48005  Angelina County, TX  18853.0
# 4  05000US48007   Aransas County, TX   6619.0
# 5  05000US48009    Archer County, TX    711.0
#
#    Income in the past 12 months below poverty level:  Male Total:  \
# 1                                             1437.0        440.0
# 2                                             1408.0        581.0
# 3                                             4808.0       2408.0
# 4                                             2268.0       1169.0
# 5                                              129.0         62.0
#
#    Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 1                 49.0                  0.0                 73.0
# 2                 49.0                 10.0                 51.0
# 3                294.0                263.0                315.0
# ...

# %%
random_county = gdf.sample()
random_county
# Out:
#            geoid                 name   Total  \
# 45  05000US48089  Colorado County, TX  6138.0
#
#     Income in the past 12 months below poverty level:  Male Total:  \
# 45                                              643.0        273.0
#
#     Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 45                  8.0                 15.0                 33.0
#
#     Male 45 to 54 years  Male 55 to 64 years  ...  Male 75 years and over  \
# 45                 19.0                 30.0  ...                     0.0
#
#     Female Total:  Female 18 to 24 years  Female 25 to 34 years  \
# 45          370.0                   19.0                   46.0
#
#     Female35 to 44 years  Female 45 to 54 years  Female 55 to 64 years  \
# 45                  28.0                   51.0                   28.0
#
#     Female 65 to 74 years  Female 75 years and over  \
# 45                   46.0                       8.0
#
#                                              geometry
# ...

# %%
random_county.iloc[0]['Female Total:']
# Out:
# 370.0

# %%
gdf['Female Total:'].head()
# Out:
# 1     997.0
# 2     827.0
# 3    2400.0
# 4    1099.0
# 5      67.0
# Name: Female Total:, dtype: float64

# %%
gdf['Female Total:'].describe()
# Out:
# count       254.000000
# mean       4902.169291
# std       20817.913211
# min           0.000000
# 25%         187.000000
# 50%         514.500000
# 75%        1706.250000
# max      227813.000000
# Name: Female Total:, dtype: float64

# %%
gdf['Female Total:'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
gdf_sorted = gdf.sort_values(by='Female Total:',ascending = False)

# %%
gdf_sorted[['geoid','Income in the past 12 months below poverty level:']].head(10)
# Out:
#             geoid  Income in the past 12 months below poverty level:
# 101  05000US48201                                           412610.0
# 108  05000US48215                                           244354.0
# 15   05000US48029                                           215257.0
# 57   05000US48113                                           199922.0
# 71   05000US48141                                           150278.0
# 31   05000US48061                                           115163.0
# 220  05000US48439                                           102135.0
# 240  05000US48479                                            72638.0
# 227  05000US48453                                            70851.0
# 178  05000US48355                                            42092.0

# %%
gdf_sorted.head(10).plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
gdf_sorted.head(255).plot(figsize=(10,10),
                          column='Income in the past 12 months below poverty level:', 
                          cmap='plasma', 
                          legend=True)
# Out:
# <AxesSubplot:>

# %%
gdf['Female Total:'] =   gdf['Female 18 to 24 years'] + gdf['Female 25 to 34 years'] + gdf['Female35 to 44 years'] + gdf['Female 45 to 54 years'] + gdf['Female 55 to 64 years'] + gdf['Female 65 to 74 years'] + gdf['Female 75 years and over']
gdf['Male Total:'] =   gdf['Male 18 to 24 years'] + gdf['Male 25 to 34 years'] + gdf['Male 35 to 44 years'] + gdf['Male 45 to 54 years'] + gdf['Male 55 to 64 years'] + gdf['Male65 to 74 years'] + gdf['Male 75 years and over']

# %%
gdf.sample(5)
# Out:
#             geoid                   name   Total  \
# 196  05000US48391     Refugio County, TX  3531.0
# 78   05000US48155       Foard County, TX   282.0
# 122  05000US48243  Jeff Davis County, TX   883.0
# 151  05000US48301      Loving County, TX    12.0
# 118  05000US48235       Irion County, TX   414.0
#
#      Income in the past 12 months below poverty level:  Male Total:  \
# 196                                              642.0        126.0
# 78                                                38.0          7.0
# 122                                                3.0          0.0
# 151                                               12.0          6.0
# 118                                               64.0         30.0
#
#      Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 196                 37.0                  3.0                 24.0
# 78                   0.0                  0.0                  0.0
# ...

# %%
gdf['Total'] = gdf['Male Total:'] + gdf['Female Total:']

# %%
gdf.sample(5)
# Out:
#             geoid               name    Total  \
# 184  05000US48367  Parker County, TX   1192.0
# 227  05000US48453  Travis County, TX  41159.0
# 138  05000US48275    Knox County, TX    132.0
# 62   05000US48123  DeWitt County, TX    979.0
# 78   05000US48155   Foard County, TX     31.0
#
#      Income in the past 12 months below poverty level:  Male Total:  \
# 184                                             2142.0        587.0
# 227                                            70851.0      17079.0
# 138                                              274.0         27.0
# 62                                              1483.0        504.0
# 78                                                38.0          7.0
#
#      Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 184                 60.0                176.0                171.0
# 227               3929.0               4823.0               3270.0
# 138                  7.0                  0.0                  7.0
# ...

# %%
list(gdf)
# Out:
# ['geoid',
#  'name',
#  'Total',
#  'Income in the past 12 months below poverty level:',
#  'Male Total:',
#  'Male 18 to 24 years',
#  'Male 25 to 34 years',
#  'Male 35 to 44 years',
#  'Male 45 to 54 years',
#  'Male 55 to 64 years',
#  'Male65 to 74 years',
#  'Male 75 years and over',
#  'Female Total:',
#  'Female 18 to 24 years',
#  'Female 25 to 34 years',
#  'Female35 to 44 years',
#  'Female 45 to 54 years',
#  'Female 55 to 64 years',
#  'Female 65 to 74 years',
#  'Female 75 years and over',
#  'geometry']

# %%
gdf['Percent of Latinas in Poverty'] = gdf['Female Total:'] / gdf['Total'] * 100

# %%
gdf.sample(5)
# Out:
#             geoid                  name   Total  \
# 50   05000US48099    Coryell County, TX   877.0
# 198  05000US48395  Robertson County, TX    99.0
# 129  05000US48257    Kaufman County, TX  2259.0
# 229  05000US48457      Tyler County, TX    32.0
# 233  05000US48465  Val Verde County, TX  4757.0
#
#      Income in the past 12 months below poverty level:  Male Total:  \
# 50                                              1749.0        368.0
# 198                                              219.0         52.0
# 129                                             4677.0        837.0
# 229                                               87.0         15.0
# 233                                             8591.0       1833.0
#
#      Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 50                  30.0                132.0                109.0
# 198                  0.0                 48.0                  0.0
# ...

# %%
gdf['Percent of Latinos in Poverty'] = gdf['Male Total:'] / gdf['Total'] * 100

# %%
gdf.sample(5)
# Out:
#             geoid                name   Total  \
# 184  05000US48367   Parker County, TX  1192.0
# 236  05000US48471   Walker County, TX  1846.0
# 54   05000US48107   Crosby County, TX   498.0
# 103  05000US48205  Hartley County, TX    74.0
# 62   05000US48123   DeWitt County, TX   979.0
#
#      Income in the past 12 months below poverty level:  Male Total:  \
# 184                                             2142.0        587.0
# 236                                             2595.0        630.0
# 54                                               903.0        192.0
# 103                                              134.0         21.0
# 62                                              1483.0        504.0
#
#      Male 18 to 24 years  Male 25 to 34 years  Male 35 to 44 years  \
# 184                 60.0                176.0                171.0
# 236                543.0                 31.0                 52.0
# 54                  37.0                 49.0                 34.0
# ...

# %%
# create the 1x2 subplots
fig, axs = plt.subplots(1, 2, figsize=(15, 12))

# name each subplot
ax1, ax2 = axs

# percent hispanic map on the left
gdf.plot(column='Percent of Latinas in Poverty', 
            cmap='inferno', 
            scheme='naturalbreaks',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, # this assigns the map to the subplot,
            legend=True
           )

ax1.axis("off")
ax1.set_title("Percent of Latinas Living Below Poverty (Past 12 Months) ")

# percent black map on the right
gdf.plot(column='Percent of Latinos in Poverty', 
            cmap='inferno', 
            scheme='naturalbreaks',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax2, # this assigns the map to the subplot
            legend=True
           )

ax2.axis("off")
ax2.set_title("Percent of Latinos 45 to 54 years Living Below Poverty (Past 12 Months) ")
# Out:
# Text(0.5, 1.0, 'Percent of Latinos 45 to 54 years Living Below Poverty (Past 12 Months) ')

# %% [markdown]
# The map visualization above represents the Male and Female percent of the total Latino population living below the poverty level for every county in Texas.
